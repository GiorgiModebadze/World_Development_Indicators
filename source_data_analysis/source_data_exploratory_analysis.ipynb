# %%
import pandas as pd
from os import listdir
import matplotlib

# %matplotlib inline

# %%
directory = '../source_data/'
files = listdir(directory)
all_files = dict()

# %%
for file in files:
    if '.csv' in file:
        all_files[file] = pd.read_csv(directory+file)
        print(file)
# Out:
# Footnotes.csv
# Indicators.csv
# SeriesNotes.csv
# Country.csv
# CountryNotes.csv
# Series.csv

# %%
all_files['Footnotes.csv'].head()
# Out:
#   Countrycode         Seriescode    Year  \
# 0         ABW     AG.LND.FRST.K2  YR1990
# 1         ABW     AG.LND.FRST.K2  YR2000
# 2         ABW     AG.LND.FRST.K2  YR2005
# 3         ABW  BX.KLT.DINV.CD.WD  YR1987
# 4         ABW  BX.KLT.DINV.CD.WD  YR1988
#
#                                          Description
# 0                                      Not specified
# 1                                      Not specified
# 2                                      Not specified
# 3  Source: United Nations Conference on Trade and...
# 4  Source: United Nations Conference on Trade and...

# %%
all_files['Indicators.csv'].head()
# Out:
#   CountryName CountryCode                                      IndicatorName  \
# 0  Arab World         ARB  Adolescent fertility rate (births per 1,000 wo...
# 1  Arab World         ARB  Age dependency ratio (% of working-age populat...
# 2  Arab World         ARB  Age dependency ratio, old (% of working-age po...
# 3  Arab World         ARB  Age dependency ratio, young (% of working-age ...
# 4  Arab World         ARB        Arms exports (SIPRI trend indicator values)
#
#     IndicatorCode  Year         Value
# 0     SP.ADO.TFRT  1960  1.335609e+02
# 1     SP.POP.DPND  1960  8.779760e+01
# 2  SP.POP.DPND.OL  1960  6.634579e+00
# 3  SP.POP.DPND.YG  1960  8.102333e+01
# 4  MS.MIL.XPRT.KD  1960  3.000000e+06

# %%
all_files['SeriesNotes.csv'].head()
# Out:
#           Seriescode    Year  \
# 0        SP.ADO.TFRT  YR1960
# 1     SP.DYN.AMRT.FE  YR1960
# 2     SP.DYN.AMRT.MA  YR1960
# 3  SP.DYN.TO65.FE.ZS  YR1960
# 4  SP.DYN.TO65.MA.ZS  YR1960
#
#                                          Description
# 0         Interpolated using data for 1957 and 1962.
# 1  Interpolated using data for 1957 and 1962, if ...
# 2  Interpolated using data for 1957 and 1962, if ...
# 3         Interpolated using data for 1957 and 1962.
# 4         Interpolated using data for 1957 and 1962.

# %%
all_files['CountryNotes.csv'].head()
# Out:
#   Countrycode         Seriescode  \
# 0         ABW  EG.EGY.PRIM.PP.KD
# 1         ABW     EG.ELC.RNEW.ZS
# 2         ABW     EG.FEC.RNEW.ZS
# 3         ABW        SM.POP.NETM
# 4         ABW        SM.POP.TOTL
#
#                                          Description
# 0  Sources: Estimated based on UN Energy Statisti...
# 1               Sources: UN Energy Statistics (2014)
# 2               Sources: UN Energy Statistics (2014)
# 3  Data sources : United Nations World Population...
# 4  Estimates are derived from data on foreign-bor...

# %%
all_files['Country.csv'].head()
# Out:
#   CountryCode       ShortName       TableName  \
# 0         AFG     Afghanistan     Afghanistan
# 1         ALB         Albania         Albania
# 2         DZA         Algeria         Algeria
# 3         ASM  American Samoa  American Samoa
# 4         ADO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1                                                NaN
# 2                                                NaN
# ...

# %%
all_files['Series.csv'].head()
# Out:
#              SeriesCode                                              Topic  \
# 0        BN.KLT.DINV.CD  Economic Policy & Debt: Balance of payments: C...
# 1  BX.KLT.DINV.WD.GD.ZS  Economic Policy & Debt: Balance of payments: C...
# 2     BX.KLT.DINV.CD.WD  Economic Policy & Debt: Balance of payments: C...
# 3     BM.KLT.DINV.GD.ZS  Economic Policy & Debt: Balance of payments: C...
# 4        BN.TRF.KOGT.CD  Economic Policy & Debt: Balance of payments: C...
#
#                                        IndicatorName ShortDefinition  \
# 0  Foreign direct investment, net (BoP, current US$)             NaN
# 1  Foreign direct investment, net inflows (% of GDP)             NaN
# 2  Foreign direct investment, net inflows (BoP, c...             NaN
# 3  Foreign direct investment, net outflows (% of ...             NaN
# 4             Net capital account (BoP, current US$)             NaN
#
#                                       LongDefinition UnitOfMeasure  \
# ...

# %%
# Lets Answer some basic Question.
# 1) How Many different countries are there in indicators and what is amount of their values
all_files['Indicators.csv'].groupby('CountryName')[['Value']].count().sort_values(by='Value')
# Out:
#                            Value
# CountryName
# St. Martin (French part)     572
# Sint Maarten (Dutch part)    681
# Curacao                     1564
# Isle of Man                 1764
# Northern Mariana Islands    1942
# Channel Islands             2739
# American Samoa              2802
# Turks and Caicos Islands    2840
# South Sudan                 3667
# Monaco                      3881
# Cayman Islands              4006
# Guam                        4265
# Liechtenstein               4282
# Virgin Islands (U.S.)       4302
# Faeroe Islands              4691
# Andorra                     4921
# Greenland                   4967
# San Marino                  5020
# Tuvalu                      5683
# Marshall Islands            5764
# Palau                       5896
# Kosovo                      6851
# Micronesia, Fed. Sts.       7126
# Aruba                       7607
# Korea, Dem. Rep.            7934
# French Polynesia            7979
# New Caledonia               8352
# ...

# %%
# 2) How Many different indicators are there in indicators and what is amount of their values
all_files['Indicators.csv'].groupby('IndicatorName')[['Value']].count().sort_values(by='Value')
# Out:
#                                                     Value
# IndicatorName
# Survey mean consumption or income per capita, b...      8
# Survey mean consumption or income per capita, t...      8
# Benefits incidence in poorest quintile (%) - Al...     67
# Adequacy of unemployment benefits and ALMP (% o...     67
# Present value of external debt (% of exports of...     69
# Children in employment, self-employed, male (% ...     70
# Children in employment, self-employed, female (...     70
# Children in employment, self-employed (% of chi...     70
# Average working hours of children, working only...     83
# Disaster risk reduction progress score (1-5 sca...     83
# Average working hours of children, working only...     85
# Presence of peace keepers (number of troops, po...     85
# Average working hours of children, working only...     85
# Average working hours of children, study and wo...     90
# Average working hours of children, study and wo...     90
# ...

# %%
# 3) Check population growth in Georgia 
all_files['Indicators.csv'][(all_files['Indicators.csv'].CountryName == 'Georgia') 
                           & (all_files['Indicators.csv'].IndicatorName == 'Population, total')].plot(x = 'Year', y = 'Value')
